# %%
import pandas as pd

# %%
df = pd.read_csv('C:/Users/29233/Desktop/UBS competition/2020_sentence_aspects_extraction.csv')
df.head()
# Out:
#    Unnamed: 0                                           sentence  \
# 0           0  Upon entering the fourth quarter in March , we...
# 1           1  In response to the impact from COVID - 19 , we...
# 2           2  During the fourth quarter , we also exited und...
# 3           3  Additionally , in June 2020 , we decided to se...
# 4           4  We have also taken actions to preserve flexibi...
#
#                  aspect1                            aspect2   CIK  \
# 0                    NaN                                NaN  1750
# 1        reduce expenses                    hiring reducing  1750
# 2  deferred arrangements  exit our joint venture investment  1750
# 3     focus core service             digital transformation  1750
# 4  financial flexibility     preserve flexibility liquidity  1750
#
#   company name   sic        sub-domain
# 0     AAR CORP  3720  AIRCRAFT & PARTS
# 1     AAR CORP  3720  AIRCRAFT & PARTS
# 2     AAR CORP  3720  AIRCRAFT & PARTS
# ...
